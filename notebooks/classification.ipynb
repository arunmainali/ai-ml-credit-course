# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier

# %%
data = pd.read_csv('../data/music.csv')

# %%
data
# Out:
#     age  gender      genre
# 0    20       1     HipHop
# 1    23       1     HipHop
# 2    25       1     HipHop
# 3    26       1       Jazz
# 4    29       1       Jazz
# 5    30       1       Jazz
# 6    31       1  Classical
# 7    33       1  Classical
# 8    37       1  Classical
# 9    20       0      Dance
# 10   21       0      Dance
# 11   25       0      Dance
# 12   26       0   Acoustic
# 13   27       0   Acoustic
# 14   30       0   Acoustic
# 15   31       0  Classical
# 16   34       0  Classical
# 17   35       0  Classical

# %%
## Exploratory Data Analysis
data.shape
# Out:
# (18, 3)

# %%
data.size
# Out:
# 54

# %%
data.describe()
# Out:
#              age     gender
# count  18.000000  18.000000
# mean   27.944444   0.500000
# std     5.127460   0.514496
# min    20.000000   0.000000
# 25%    25.000000   0.000000
# 50%    28.000000   0.500000
# 75%    31.000000   1.000000
# max    37.000000   1.000000

# %%
data.head()
# Out:
#    age  gender   genre
# 0   20       1  HipHop
# 1   23       1  HipHop
# 2   25       1  HipHop
# 3   26       1    Jazz
# 4   29       1    Jazz

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   age     18 non-null     int64
#  1   gender  18 non-null     int64
#  2   genre   18 non-null     object
# dtypes: int64(2), object(1)
# memory usage: 560.0+ bytes

# %%
data.dtypes
# Out:
# age        int64
# gender     int64
# genre     object
# dtype: object

# %%
data.tail(4)
# Out:
#     age  gender      genre
# 14   30       0   Acoustic
# 15   31       0  Classical
# 16   34       0  Classical
# 17   35       0  Classical

# %%
data.sample(6)
# Out:
#    age  gender      genre
# 1   23       1     HipHop
# 2   25       1     HipHop
# 8   37       1  Classical
# 5   30       1       Jazz
# 7   33       1  Classical
# 6   31       1  Classical

# %%
data.values
# Out:
# array([[20, 1, 'HipHop'],
#        [23, 1, 'HipHop'],
#        [25, 1, 'HipHop'],
#        [26, 1, 'Jazz'],
#        [29, 1, 'Jazz'],
#        [30, 1, 'Jazz'],
#        [31, 1, 'Classical'],
#        [33, 1, 'Classical'],
#        [37, 1, 'Classical'],
#        [20, 0, 'Dance'],
#        [21, 0, 'Dance'],
#        [25, 0, 'Dance'],
#        [26, 0, 'Acoustic'],
#        [27, 0, 'Acoustic'],
#        [30, 0, 'Acoustic'],
#        [31, 0, 'Classical'],
#        [34, 0, 'Classical'],
#        [35, 0, 'Classical']], dtype=object)

# %%
data.plot()
# Out:
# <Axes: >

# %% [markdown]
# ## Pandas --> Data Analysis Library (provides dataframe)
# ## NumPy (Numerical Python) --> Supprts multidimensional arrays
# ## scikit-learn --> helps to built ML models
# ## matplotlib --> default visualization tools of Python
# ## seaborn --> provides fancy statistics chart
# ## bokeh --> provides the interactive charts

# %%
data.columns
# Out:
# Index(['age', 'gender', 'genre'], dtype='object')

# %%
X = data.drop(columns = ['genre'])
X = data[['age', 'gender']]
X
# Out:
#     age  gender
# 0    20       1
# 1    23       1
# 2    25       1
# 3    26       1
# 4    29       1
# 5    30       1
# 6    31       1
# 7    33       1
# 8    37       1
# 9    20       0
# 10   21       0
# 11   25       0
# 12   26       0
# 13   27       0
# 14   30       0
# 15   31       0
# 16   34       0
# 17   35       0

# %%
Y = data['genre']
Y
# Out:
# 0        HipHop
# 1        HipHop
# 2        HipHop
# 3          Jazz
# 4          Jazz
# 5          Jazz
# 6     Classical
# 7     Classical
# 8     Classical
# 9         Dance
# 10        Dance
# 11        Dance
# 12     Acoustic
# 13     Acoustic
# 14     Acoustic
# 15    Classical
# 16    Classical
# 17    Classical
# Name: genre, dtype: object

# %%
# Machine Learning > Supervised > Classification > Decision Tree
# Just to predict

model = DecisionTreeClassifier()
model
# Out:
# DecisionTreeClassifier()

# %%
model.fit(X.values, Y.values)
# Out:
# DecisionTreeClassifier()

# %%
model.predict([[21, 1]])
# Out:
# array(['HipHop'], dtype=object)

# %%
model.predict([[25.5, 1]])
# Out:
# array(['HipHop'], dtype=object)

# %%
from sklearn.svm import SVC

# %%
model = SVC(degree=2)
model.fit(X.values, Y.values)
# Out:
# SVC(degree=2)

# %%
model.predict([[21, 2]])
# Out:
# array(['HipHop'], dtype=object)

# %%
X.shape
# Out:
# (18, 2)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2)
model = DecisionTreeClassifier()
model.fit(X_train.values, Y_train.values)
prediction = model.predict(X_test.values)

# %%
from sklearn.metrics import accuracy_score
score = accuracy_score(prediction, Y_test)
print(score)
# Out:
# 0.75

# %%
X_train.shape, Y_train.shape, X_test.shape, Y_test.shape
# Out:
# ((14, 2), (14,), (4, 2), (4,))

# %% [markdown]
# ## ML:
# - Supervised: Labelled data
#     * Regression: value
#     * Classification: class
# - Unsupervised: Unlabelled data
# - Renforcement:
#
# X --> features
# y --> target
